# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
Image.open("/raid/kientdt/shared_drive_cv/ocr/kientdt/LRANet/data/totaltext/imgs/training/training/img11.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=578x500>

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import cv2

# File paths
mat_file_path = '/raid/kientdt/shared_drive_cv/ocr/kientdt/LRANet/data/totaltext/annotations/training/poly_gt_img11.mat'
image_path = '/raid/kientdt/shared_drive_cv/ocr/kientdt/LRANet/data/totaltext/training/img11.jpg'  # Corresponding image

# Load the .mat file
mat_data = scipy.io.loadmat(mat_file_path)

# Check the keys in the .mat file to explore its structure
print("Keys in .mat file:", mat_data.keys())
# Out:
# Keys in .mat file: dict_keys(['__header__', '__version__', '__globals__', 'polygt'])

# %%
mat_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Wed Oct  4 14:41:53 2017',
#  '__version__': '1.0',
#  '__globals__': [],
#  'polygt': array([[array(['x:'], dtype='<U2'),
#          array([[214, 280, 362, 349, 284, 231]], dtype=int16),
#          array(['y:'], dtype='<U2'),
#          array([[325, 290, 320, 347, 316, 346]], dtype=int16),
#          array(['ASRAMA'], dtype='<U6'), array(['c'], dtype='<U1')],
#         [array(['x:'], dtype='<U2'),
#          array([[230, 292, 358, 384, 293, 211]], dtype=int16),
#          array(['y:'], dtype='<U2'),
#          array([[402, 430, 395, 419, 463, 425]], dtype=int16),
#          array(['PELAJAR'], dtype='<U7'), array(['c'], dtype='<U1')],
#         [array(['x:'], dtype='<U2'),
#          array([[ 53, 120, 121,  56]], dtype=int16),
#          array(['y:'], dtype='<U2'),
#          array([[446, 443, 456, 458]], dtype=int16),
#          array(['PERUNDING'], dtype='<U9'), array(['h'], dtype='<U1')],
# ...
